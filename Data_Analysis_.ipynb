# %% [markdown]
# # Task 1: Importing Data

# %%
# !pip install tabula-py
# Out:
# ...
#      |████████████████████████████████| 12.0 MB 5.1 MB/s
# ...

# %%
import tabula
import pandas as pd

# %% [markdown]
# ## Attempt to read pdf

# %%
df = tabula.read_pdf('/content/drive/MyDrive/Temp_stuff/work_temp/PDA - Loans_Database_Table.pdf', pages='all')

# %%
tables = tabula.read_pdf('/content/drive/MyDrive/Temp_stuff/work_temp/PDA - Loans_Database_Table.pdf', pages='all', pandas_options={'header': None})

# %%
tables[0].head()
# Out:
#         0       1        2           3         4              5   \
# 0  Loan_ID  Gender  Married  Dependents  Graduate  Self_Employed
# 1     1002       1        0           0         1              0
# 2     1003       1        1           1         1              0
# 3     1005       1        1           0         1              1
# 4     1006       1        1           0         0              0
#
#                 6                  7           8                 9   \
# 0  ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# 1             5849                  0         128               360
# 2             4583               1508         128               360
# 3             3000                  0          66               360
# 4             2583               2358         120               360
#
#                10             11           12
# 0  Credit_History  Property_Area  Loan_Status
# 1               1              1            Y
# ...

# %%
tables_df = pd.concat(tables)

# %%
tables_df
# Out:
#          0       1        2           3         4              5   \
# 0   Loan_ID  Gender  Married  Dependents  Graduate  Self_Employed
# 1      1002       1        0           0         1              0
# 2      1003       1        1           1         1              0
# 3      1005       1        1           0         1              1
# 4      1006       1        1           0         0              0
# ..      ...     ...      ...         ...       ...            ...
# 17     2265       1        1           2         0              0
# 18     2266       1        1           2         1              0
# 19     2272       1        1           2         1              0
# 20     2277       2        0           0         1              0
# 21     2281       1        1           0         1              0
#
#                  6                  7           8                 9   \
# 0   ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# ...

# %%
tables_df.columns = df[0].columns

# %%
tables_df
# Out:
#     Loan_ID  Gender  Married  Dependents  Graduate  Self_Employed  \
# 0   Loan_ID  Gender  Married  Dependents  Graduate  Self_Employed
# 1      1002       1        0           0         1              0
# 2      1003       1        1           1         1              0
# 3      1005       1        1           0         1              1
# 4      1006       1        1           0         0              0
# ..      ...     ...      ...         ...       ...            ...
# 17     2265       1        1           2         0              0
# 18     2266       1        1           2         1              0
# 19     2272       1        1           2         1              0
# 20     2277       2        0           0         1              0
# 21     2281       1        1           0         1              0
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0   ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# ...

# %%
tables_df = tables_df.drop(labels=0, axis=0)
tables_df
# Out:
#    Loan_ID Gender Married Dependents Graduate Self_Employed ApplicantIncome  \
# 1     1002      1       0          0        1             0            5849
# 2     1003      1       1          1        1             0            4583
# 3     1005      1       1          0        1             1            3000
# 4     1006      1       1          0        0             0            2583
# 5     1008      1       0          0        1             0            6000
# ..     ...    ...     ...        ...      ...           ...             ...
# 17    2265      1       1          2        0             0            1993
# 18    2266      1       1          2        1             0            3100
# 19    2272      1       1          2        1             0            3276
# 20    2277      2       0          0        1             0            3180
# 21    2281      1       1          0        1             0            3033
#
# ...

# %%
df1 = tables_df

# %% [markdown]
# ### Unnecesary Attempts

# %%
len(df)
# Out:
# 14

# %%
df[0].head()
# Out:
#    Loan_ID  Gender  Married  Dependents  Graduate  Self_Employed  \
# 0     1002       1        0           0         1              0
# 1     1003       1        1           1         1              0
# 2     1005       1        1           0         1              1
# 3     1006       1        1           0         0              0
# 4     1008       1        0           0         1              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                  0         128               360
# 1             4583               1508         128               360
# 2             3000                  0          66               360
# 3             2583               2358         120               360
# 4             6000                  0         141               360
#
#    Credit_History  Property_Area Loan_Status
# 0               1              1           Y
# 1               1              3           N
# ...

# %%
col_names = df[0].columns

# %%
df[1].head()
# Out:
#    1086  1  0  0.1  0.2  0.3  1442   0.4   35  360  1.1  1.2  N
# 0  1087  2  0    2    1    0  3750  2083  120  360    1    2  Y
# 1  1091  1  1    1    1    0  4166  3369  201  360    0    1  N
# 2  1095  1  0    0    1    0  3167     0   74  360    1    1  N
# 3  1097  1  0    1    1    1  4692     0  106  360    1    3  N
# 4  1098  1  1    0    1    0  3500  1667  114  360    1    2  Y

# %%
for i in df:
  i.columns = col_names

# %%
df[1].head()
# Out:
#    Loan_ID  Gender  Married  Dependents  Graduate  Self_Employed  \
# 0     1087       2        0           2         1              0
# 1     1091       1        1           1         1              0
# 2     1095       1        0           0         1              0
# 3     1097       1        0           1         1              1
# 4     1098       1        1           0         1              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             3750               2083         120               360
# 1             4166               3369         201               360
# 2             3167                  0          74               360
# 3             4692                  0         106               360
# 4             3500               1667         114               360
#
#    Credit_History  Property_Area Loan_Status
# 0               1              2           Y
# 1               0              1           N
# ...

# %%
loan_df = pd.concat(df)

# %%
loan_df.shape
# Out:
# (385, 74)

# %% [markdown]
# ## Reading the excel data

# %%
df2 = pd.read_excel('/content/drive/MyDrive/Temp_stuff/work_temp/PDA - Zappy Loan Data.xlsx')

# %%
df2.shape
# Out:
# (247, 13)

# %% [markdown]
# # Task 2: Exploring the Datasets

# %%
df2.columns == df1.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
df1.tail()
# Out:
#    Loan_ID Gender Married Dependents Graduate Self_Employed ApplicantIncome  \
# 17    2265      1       1          2        0             0            1993
# 18    2266      1       1          2        1             0            3100
# 19    2272      1       1          2        1             0            3276
# 20    2277      2       0          0        1             0            3180
# 21    2281      1       1          0        1             0            3033
#
#    CoapplicantIncome LoanAmount Loan_Amount_Term Credit_History Property_Area  \
# 17              1625        113              180              1             2
# 18              1400        113              360              1             1
# 19               484        135              360              0             2
# 20                 0         71              360              0             1
# 21              1459         95              360              1             1
#
#    Loan_Status
# 17           Y
# ...

# %%
df2
# Out:
#      Loan_ID  Gender  Married  Dependents  Graduate  Self_Employed  \
# 0       2284       1        0           0         0              0
# 1       2287       2        0           0         1              0
# 2       2288       1        1           2         0              0
# 3       2296       1        0           0         0              0
# 4       2297       1        0           0         1              0
# ..       ...     ...      ...         ...       ...            ...
# 242     2978       2        0           0         1              0
# 243     2979       1        1           3         1              0
# 244     2983       1        1           1         1              0
# 245     2984       1        1           2         1              0
# 246     2990       2        0           0         1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               3902             1666.0         109               333
# ...

# %%
lis = [df1, df2]
df1 = pd.concat(lis)
df1
# Out:
#     Loan_ID Gender Married Dependents Graduate Self_Employed ApplicantIncome  \
# 1      1002      1       0          0        1             0            5849
# 2      1003      1       1          1        1             0            4583
# 3      1005      1       1          0        1             1            3000
# 4      1006      1       1          0        0             0            2583
# 5      1008      1       0          0        1             0            6000
# ..      ...    ...     ...        ...      ...           ...             ...
# 242    2978      2       0          0        1             0            2900
# 243    2979      1       1          3        1             0            4106
# 244    2983      1       1          1        1             0            8072
# 245    2984      1       1          2        1             0            7583
# 246    2990      2       0          0        1             1            4583
#
# ...

# %% [markdown]
# ## Working on the combined Data set

# %%
df1.shape
# Out:
# (632, 13)

# %%
df1.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Graduate',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 632 entries, 1 to 246
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            632 non-null    object
#  1   Gender             632 non-null    object
#  2   Married            632 non-null    object
#  3   Dependents         632 non-null    object
#  4   Graduate           632 non-null    object
#  5   Self_Employed      632 non-null    object
#  6   ApplicantIncome    632 non-null    object
#  7   CoapplicantIncome  632 non-null    object
#  8   LoanAmount         632 non-null    object
#  9   Loan_Amount_Term   632 non-null    object
#  10  Credit_History     632 non-null    object
#  11  Property_Area      632 non-null    object
#  12  Loan_Status        632 non-null    object
# dtypes: object(13)
# memory usage: 69.1+ KB

# %%
df1.describe()
# Out:
#         Loan_ID  Gender  Married  Dependents  Graduate  Self_Employed  \
# count       632     632      632         632       632            632
# unique      602       4        4           8         4              4
# top        1907       1        1           0         1              0
# freq          2     486      386         362       477            523
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count               632                632         632               632
# unique              508                289         223                14
# top                2500                  0         128               360
# freq                  8                268          23               306
#
#         Credit_History  Property_Area Loan_Status
# count              632            632         632
# unique               4              6           2
# top                  1              2           Y
# ...

# %%
df1.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Graduate             0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df1.duplicated().value_counts()
# Out:
# False    629
# True       3
# dtype: int64

# %%
df1 = df1.drop_duplicates()

# %%
df1.shape
# Out:
# (629, 13)

# %%
df1['Loan_ID']
# Out:
# 1      1002
# 2      1003
# 3      1005
# 4      1006
# 5      1008
#        ...
# 242    2978
# 243    2979
# 244    2983
# 245    2984
# 246    2990
# Name: Loan_ID, Length: 629, dtype: object

# %% [markdown]
# The percentage of female applicants that had their loan approved

# %%
df1['Loan_Status']
# Out:
# 1      Y
# 2      N
# 3      Y
# 4      Y
# 5      Y
#       ..
# 242    Y
# 243    Y
# 244    Y
# 245    Y
# 246    N
# Name: Loan_Status, Length: 629, dtype: object

# %%
import numpy as np
'''conditions = [
    df1['Gender'].eq(2) & df['Loan_Status'].eq(df['Y']),
]

choices = [1]
female_loan_sanctioned = np.select(conditions, choices, default=0)'''
# Out:
# "conditions = [\n    df1['Gender'].eq(2) & df['Loan_Status'].eq(df['Y']),\n]\n\nchoices = [1]\nfemale_loan_sanctioned = np.select(conditions, choices, default=0)"

# %%
female_loan_sanctioned = np.where( ( (df1['Gender'] == 2) & (df1['Loan_Status'] == 'Y' ) ))

# %%
female_loan_sanctioned
# Out:
# (array([ 28,  36,  44,  48,  49,  50,  78,  93, 108, 110, 112, 115, 117,
#         118, 121, 140, 141, 178, 191, 192, 198, 199, 212, 225, 229, 230,
#         247, 254, 260, 261, 270, 274, 279, 287, 292, 296, 300, 302, 312,
#         318, 328, 342, 343, 358, 362, 369, 390, 392, 394, 400, 404, 408,
#         416, 420, 430, 445, 450, 454, 478, 483, 488, 495, 508, 510, 515,
#         516, 524, 531, 549, 555, 557, 559, 571, 574, 576, 597, 602, 619,
#         624]),)

# %%
df1.iloc[[28]]
# Out:
#   Loan_ID Gender Married Dependents Graduate Self_Employed ApplicantIncome  \
# 1    1087      2       0          2        1             0            3750
#
#   CoapplicantIncome LoanAmount Loan_Amount_Term Credit_History Property_Area  \
# 1              2083        120              360              1             2
#
#   Loan_Status
# 1           Y

# %%
len(female_loan_sanctioned[0])
# Out:
# 79

# %%
len(df1)
# Out:
# 629

# %%
percentage_femal_approval = (len(female_loan_sanctioned[0]) / len(df1)) * 100

# %%
percentage_femal_approval
# Out:
# 12.559618441971383

# %% [markdown]
# The average income of all applicants

# %%
total_sum = df1['ApplicantIncome'].astype(float).sum()

# %%
average_income = total_sum / len(df1)

# %%
average_income
# Out:
# 5356.003179650238

# %% [markdown]
# The average income of all applicants that are self-employed

# %%
self_employed_income = np.where( ( (df1['Self_Employed'] == 1) ))

# %%
self_employed_income[0]
# Out:
# array([ 31,  43,  53,  60,  66,  69,  72,  75,  77,  79, 110, 124, 126,
#        129, 133, 138, 146, 168, 179, 180, 182, 193, 205, 206, 219, 222,
#        229, 235, 237, 244, 246, 255, 271, 277, 303, 308, 314, 316, 323,
#        324, 326, 341, 352, 358, 360, 370, 391, 401, 425, 432, 445, 453,
#        454, 460, 464, 469, 475, 485, 488, 490, 493, 503, 508, 513, 523,
#        537, 538, 540, 549, 565, 572, 576, 578, 604, 606, 607, 609, 611,
#        613, 628])

# %%
temp = df1['ApplicantIncome'].iloc[[611]]

# %%
df1.iloc[[611]]
# Out:
#     Loan_ID Gender Married Dependents Graduate Self_Employed ApplicantIncome  \
# 229    2941      1       1          2        0             1            6383
#
#     CoapplicantIncome LoanAmount Loan_Amount_Term Credit_History  \
# 229            1000.0        187              333              1
#
#     Property_Area Loan_Status
# 229             3           N

# %%
suum = 0
for i in self_employed_income[0]:
  suum = suum + int(df1['ApplicantIncome'].iloc[[i]])

# %%
average_income_self_employeed = suum / len(df1)

# %%
average_income_self_employeed
# Out:
# 940.0683624801272

# %% [markdown]
# The average income of all applicants that are not self-employed

# %%
non_self_employed_income = np.where( ( (df1['Self_Employed'] == 0) ))

# %%
suum2 = 0
for i in non_self_employed_income[0]:
  suum2 = suum2 + int(df1['ApplicantIncome'].iloc[[i]])

# %%
average_income_non_self_employeed = suum2 / len(df1)
average_income_non_self_employeed
# Out:
# 4223.569157392687

# %% [markdown]
# The average income of all graduate applicants

# %%
graduates = np.where( ( (df1['Graduate'] == 1) ))

# %%
suum3 = 0
for i in graduates[0]:
  suum3 = suum3 + int(df1['ApplicantIncome'].iloc[[i]])

# %%
average_income_graduate = suum3 / len(df1)
average_income_graduate
# Out:
# 4403.885532591415

# %% [markdown]
# The percentage of graduate applicants that had their loan status approved

# %%
graduate_sanctioned = np.where( ( (df1['Graduate'] == 1) & (df1['Loan_Status'] == 'Y' ) ))

# %%
len(graduate_sanctioned[0])
# Out:
# 338

# %%
percentage_graduate_approval = (len(graduate_sanctioned[0])/len(df1)) * 100

# %%
percentage_graduate_approval
# Out:
# 53.73608903020668
